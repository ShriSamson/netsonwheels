# %%
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize

# %%
# not working 
da=json.load((open('yelp_academic_dataset_business.json',encoding="utf8")))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-b421fb794da9> in <module>()
#       1 # not working
# ----> 2 da=json.load((open('yelp_academic_dataset_business.json',encoding="utf8")))
#
# C:\Users\Rajkumar\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# C:\Users\Rajkumar\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
# ...

# %%
def yelp2df(filename,):
   with open(filename, 'r',encoding="utf8") as f:
       reviews = f.readlines()

   reviews_json=[json.loads(review) for review in reviews]
   df = pd.DataFrame(reviews_json)

   return df

# %%
df_b=yelp2df('yelp_academic_dataset_business.json')

# %%
df_u=yelp2df('yelp_academic_dataset_user.json')

# %%
df_u
# Out:
#          average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0                 3.59             4192               79              4192
# 1                 4.29              144               11               144
# 2                 4.15               36                1                36
# 3                 3.82               54                6                54
# 4                 2.97                0                0                 0
# 5                 3.76               19                0                19
# 6                 4.04               33                1                33
# 7                 3.73               18                4                18
# 8                 3.42                0                0                 0
# 9                 3.39                7                0                 7
# 10                3.92                2                0                 2
# ...

# %%
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144072 entries, 0 to 144071
# Data columns (total 16 columns):
# address         144072 non-null object
# attributes      127162 non-null object
# business_id     144072 non-null object
# categories      143747 non-null object
# city            144072 non-null object
# hours           102464 non-null object
# is_open         144072 non-null int64
# latitude        144072 non-null float64
# longitude       144072 non-null float64
# name            144072 non-null object
# neighborhood    144072 non-null object
# postal_code     144072 non-null object
# review_count    144072 non-null int64
# stars           144072 non-null float64
# state           144072 non-null object
# type            144072 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 17.6+ MB

# %%
df_u
# Out:
#          average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0                 3.59             4192               79              4192
# 1                 4.29              144               11               144
# 2                 4.15               36                1                36
# 3                 3.82               54                6                54
# 4                 2.97                0                0                 0
# 5                 3.76               19                0                19
# 6                 4.04               33                1                33
# 7                 3.73               18                4                18
# 8                 3.42                0                0                 0
# 9                 3.39                7                0                 7
# 10                3.92                2                0                 2
# ...

# %%
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144072 entries, 0 to 144071
# Data columns (total 16 columns):
# address         144072 non-null object
# attributes      127162 non-null object
# business_id     144072 non-null object
# categories      143747 non-null object
# city            144072 non-null object
# hours           102464 non-null object
# is_open         144072 non-null int64
# latitude        144072 non-null float64
# longitude       144072 non-null float64
# name            144072 non-null object
# neighborhood    144072 non-null object
# postal_code     144072 non-null object
# review_count    144072 non-null int64
# stars           144072 non-null float64
# state           144072 non-null object
# type            144072 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 17.6+ MB

# %%
#df_bsubset = df_b[['business_id','categories','city']['city' == 'Las Vegas']]

df_bsubset = df_b[df_b['city'] == 'Las Vegas' ]

# %%
df_bsubset=df_bsubset[['business_id','categories','city']]

# %%
df_bsubset
# Out:
#                    business_id  \
# 1       LTlCaCGZE14GuaUXUGbamg
# 26      AGN788ObhwXu7rb8MEejIA
# 36      XK5w8XnbP8CdeoB44kn1bg
# 37      saWZO6hB4B8P-mIzS1--Xw
# 54      U8_JrQdIpuTKw60vjc1-cw
# 55      HanDs-I7qnmd-WXUrKP5HQ
# 61      SGpnlO6TBpR_IFgOa3F8EQ
# 71      hMh9XOwNQcu31NAOCqhAEw
# 72      pmJqSsCfgbo3TxPWpQNLIw
# 73      4aU5TN3Q5SQB7DLeXza7dg
# 74      -gNGk0SIbdBNSRBrzQAeSA
# 75      PhGpWmiHPlgCjQNb6qYZYA
# 102     kUUBBLBHCasOl2a5nW9nAw
# 103     A2pZTpFXWC38z506XIhnBQ
# 125     P4l4CgT90FgppT5krYnNzw
# 129     4tzmCT04wTAbbiZFKo2cPQ
# 130     42TfdCOVUv03szlNa6f9pg
# 134     Fw1avANNIrg-OEDd2uJFRQ
# 142     kWWNy5NT2RRqXi0aycV5Fw
# 154     InDH4ZQ_byiQ5PyaqgHI8Q
# 168     piGQNN6ECbSC0agHhvoVeg
# 177     WleVOQ9YhBYl4SWrlsLDhA
# 178     ktGhPGyBLgAjHI90EHFS4w
# 179     gMUAn6xcuE-TbY1seFw_Ww
# 180     LlUCcvt-PnFN9QB_33e8sA
# 184     kUntNQ5P9IrRzEoHdRxV-w
# 185     EU3DE9JD5kFcgchB_P4LNw
# 186     ZQABM9tbbMKBBmMPCAe2uA
# 191     wRS_Ct8nxHrTZOj4rWseDw
# ...

# %%
df_bsubset1=df_bsubset[df_bsubset['categories']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-31b46ed8126f> in <module>()
# ----> 1 df_bsubset1=df_bsubset[df_bsubset['categories']]
#
# C:\Users\Rajkumar\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# C:\Users\Rajkumar\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2078     def _getitem_array(self, key):
#    2079         # also raises Exception if object array with NA values
# -> 2080         if com.is_bool_indexer(key):
#    2081             # warning here just in case -- previously __setitem__ was
# ...

# %%
df_bsubset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22892 entries, 1 to 144054
# Data columns (total 3 columns):
# business_id    22892 non-null object
# categories     22830 non-null object
# city           22892 non-null object
# dtypes: object(3)
# memory usage: 715.4+ KB

# %%
df_bsubset1
# Out:
# Empty DataFrame
# Columns: [business_id, categories, city]
# Index: []
